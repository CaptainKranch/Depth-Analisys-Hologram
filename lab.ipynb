# %%
import pandas as pd

# %%
df = pd.read_csv('data/holo.csv')

# %%
value = ['Single Carrier', 'Undefined']

df = df[df.plan_type.isin(value) == False ]

# %%
var = df['name'].value_counts()

df = df[df['name'].isin(var[var>1].index)]

# %%
serial_numbers = df['name'].value_counts()

sn_size = serial_numbers.size

count=0

one_carrier_list = []

for _ in range(sn_size):
    controller_serial_number =  serial_numbers.keys()[_]
    
    Sdf = df.loc[df['name'].isin([controller_serial_number])]
    value = Sdf['network_name'].value_counts()
    value_size = value.size

    if value_size == 1:
        one_carrier_list.append(controller_serial_number)
        df = df[~((df['name'] == controller_serial_number))]
    else:
        count+=1

# %%
df = df.drop(['session_begin', 'imei', 'sim'], axis = 1)

df['timestamp'] = df['timestamp'].apply(pd.to_datetime)

df['timestamp'] = df['timestamp'].dt.date

groupby_name_timestamp = df.groupby(['name','timestamp'], as_index=False)['network_name'].agg(['value_counts'])

# %%
groupby_name_timestamp.to_csv('data/holo_groupby_name_timestamp.csv')

# %%
df = pd.read_csv('data/holo_groupby_name_timestamp.csv')

date = df['timestamp'].value_counts()
date_size = date.size

delete = []
no_delete = []
date_list = []
count = 0

for _ in range(date_size):
    
    current_date = date.keys()[_]
    date_df = df.loc[df['timestamp'].isin([current_date])]

    sn = date_df['name'].value_counts()
    sn_size = sn.size

    for __ in range(sn_size):
        sn_count = sn[__]
        sn_var = sn.keys()[__]

        if sn_count == 1:
            delete.append(sn_var)
            date_list.append(current_date)
            df = df.loc[~((df['name'] == sn_var) & (df['timestamp'] == current_date)),:]
            #df = df.drop([df.index[_]])
            
        else:
            no_delete.append(sn_var)
            count+=1

# %% [markdown]
# ACA VAMOS A SACAR LA INFORMACION QUE DANIEL QUIERE

# %%
sn_list = []

sns = df['name'].value_counts()
sns_size = sns.size

for _ in range(sns_size):
    current_sn = sns.keys()[_]
    sn_list.append(current_sn)

# %%
timeline_df = pd.read_csv('data/holo.csv')

# %%
timeline_df = timeline_df.drop(['timestamp'], axis = 1)

timeline_df['session_begin'] = timeline_df['session_begin'].apply(pd.to_datetime)

# %%
timeline_df = timeline_df[timeline_df['name'].isin(sn_list)]

# %%
timeline_df
# Out:
#              name           sim      plan_type          imei  \
# 39       92001496  8.940000e+18  Multi Carrier  8.670000e+14
# 80       92001496  8.940000e+18  Multi Carrier  8.670000e+14
# 95       92001496  8.940000e+18  Multi Carrier  8.670000e+14
# 104      92009678  8.940000e+18  Multi Carrier  8.670000e+14
# 107      92001496  8.940000e+18  Multi Carrier  8.670000e+14
# ...           ...           ...            ...           ...
# 1048537  92014334  8.940000e+18  Multi Carrier  8.670000e+14
# 1048541  92009149  8.940000e+18  Multi Carrier  8.670000e+14
# 1048553  92010219  8.940000e+18  Multi Carrier  8.670000e+14
# 1048556  92006010  8.940000e+18  Multi Carrier  8.670000e+14
# 1048571  92005905  8.940000e+18  Multi Carrier  8.670000e+14
#
#               session_begin  duration    bytes       network_name
# 39      2021-11-25 00:04:00         1        0  T-Mobile USA, Inc
# 80      2021-11-25 00:05:00       220        0  T-Mobile USA, Inc
# 95      2021-11-25 00:01:00       134        0  T-Mobile USA, Inc
# 104     2021-11-25 00:20:00       306    46074      AT&T Mobility
# 107     2021-11-25 00:19:00         1        0  T-Mobile USA, Inc
# ...                     ...       ...      ...                ...
# 1048537 2022-01-15 02:45:00     25189   789175      AT&T Mobility
# 1048541 2022-01-15 03:08:00     25189  1344458      AT&T Mobility
# 1048553 2022-01-15 03:14:00     25186  1256793      AT&T Mobility
# 1048556 2022-01-15 03:34:00     25186   660722      AT&T Mobility
# 1048571 2022-01-15 03:20:00     25187     4704      AT&T Mobility
#
# [255078 rows x 8 columns]

# %%
curr_net = timeline_df.iloc[0]
curr_net = curr_net[0]
curr_net
# Out:
# '92001496'

# %%
all_sns = timeline_df['name'].value_counts()
sns_size = all_sns.size

help_net = []
help_cont = []
sum_duration_list = []

first_net = timeline_df.iloc[0]
first_net = first_net[-1]
help_net.append(first_net)

first_cont = timeline_df.iloc[0]
first_cont = first_cont[1]
help_cont.append(first_cont)


duration_list = timeline_df['duration'].values
sn_list = timeline_df['name'].values

for _ in range(sns_size):
    curr_net = timeline_df.iloc[_ + 1]
    curr_net = curr_net[-1]

    curr_cont = timeline_df.iloc[_ + 1]
    curr_cont = curr_cont[1]

    if curr_net == help_net[-1] and curr_cont == help_cont[-1]:
        sum_duration = duration_list[_ + 1] + duration_list[_]
        sum_duration_list.append(sum_duration)
        help_net.append(curr_net)
        help_cont.append(curr_cont)
        owo = timeline_df.drop([timeline_df.index[_]])
    else:
        help_net.append(curr_net)
        help_cont.append(curr_cont)

# %%
owo.drop(['duration'], axis=1)
owo['sum_duration'] = sum_duration_list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\imsoa\Documents\GitHub\Depth-Analisys-Hologram\lab.ipynb Cell 17' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/imsoa/Documents/GitHub/Depth-Analisys-Hologram/lab.ipynb#ch0000031?line=0'>1</a> owo.drop(['duration'], axis=1)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/imsoa/Documents/GitHub/Depth-Analisys-Hologram/lab.ipynb#ch0000031?line=1'>2</a> owo['sum_duration'] = sum_duration_list
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:3612, in DataFrame.__setitem__(self, key, value)
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3608'>3609</a>     self._setitem_array([key], value)
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3609'>3610</a> else:
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3610'>3611</a>     # set column
# -> <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3611'>3612</a>     self._set_item(key, value)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:3784, in DataFrame._set_item(self, key, value)
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3773'>3774</a> def _set_item(self, key, value) -> None:
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3774'>3775</a>     """
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3775'>3776</a>     Add series to DataFrame in specified column.
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3776'>3777</a>
#    (...)
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3781'>3782</a>     ensure homogeneity.
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3782'>3783</a>     """
# -> <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3783'>3784</a>     value = self._sanitize_column(value)
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3785'>3786</a>     if (
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3786'>3787</a>         key in self.columns
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3787'>3788</a>         and value.ndim == 1
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3788'>3789</a>         and not is_extension_array_dtype(value)
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3789'>3790</a>     ):
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3790'>3791</a>         # broadcast across multiple columns if necessary
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=3791'>3792</a>         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:4509, in DataFrame._sanitize_column(self, value)
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4505'>4506</a>     return _reindex_for_setitem(value, self.index)
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4507'>4508</a> if is_list_like(value):
# -> <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4508'>4509</a>     com.require_length_match(value, self.index)
#    <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/frame.py?line=4509'>4510</a> return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\common.py:531, in require_length_match(data, index)
#     <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/common.py?line=526'>527</a> """
#     <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/common.py?line=527'>528</a> Check the length of data matches the length of the index.
#     <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/common.py?line=528'>529</a> """
#     <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/common.py?line=529'>530</a> if len(data) != len(index):
# --> <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/common.py?line=530'>531</a>     raise ValueError(
#     <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/common.py?line=531'>532</a>         "Length of values "
#     <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/common.py?line=532'>533</a>         f"({len(data)}) "
#     <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/common.py?line=533'>534</a>         "does not match length of index "
#     <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/common.py?line=534'>535</a>         f"({len(index)})"
#     <a href='file:///~/AppData/Roaming/Python/Python310/site-packages/pandas/core/common.py?line=535'>536</a>     )
#
# ValueError: Length of values (507) does not match length of index (255077)
